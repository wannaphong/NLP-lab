# %%
# !pip install --pre pythainlp
# Out:
# Collecting pythainlp
#   Downloading https://files.pythonhosted.org/packages/f4/07/3397d076776fd27580574807f63b0d63ddec727d00739ccc74feeeda1c4f/pythainlp-2.1.dev8-py3-none-any.whl (11.1MB)
#      |████████████████████████████████| 11.1MB 1.4MB/s
# Requirement already satisfied: dill>=0.3.0 in /usr/local/lib/python3.6/dist-packages (from pythainlp) (0.3.1.1)
# Collecting tinydb>=3.0
#   Downloading https://files.pythonhosted.org/packages/9b/83/2d46115b89640e9b85b94df47216547396e94125245dd3ade186036ce976/tinydb-3.15.1-py2.py3-none-any.whl
# Collecting requests>=2.22.0
#   Downloading https://files.pythonhosted.org/packages/51/bd/23c926cd341ea6b7dd0b2a00aba99ae0f828be89d72b2190f27c11d4b7fb/requests-2.22.0-py2.py3-none-any.whl (57kB)
#      |████████████████████████████████| 61kB 8.9MB/s
# Collecting nltk>=3.3
#   Downloading https://files.pythonhosted.org/packages/f6/1d/d925cfb4f324ede997f6d47bea4d9babba51b49e87a767c170b77005889d/nltk-3.4.5.zip (1.5MB)
#      |████████████████████████████████| 1.5MB 44.7MB/s
# Requirement already satisfied: tqdm>=4.1 in /usr/local/lib/python3.6/dist-packages (from pythainlp) (4.28.1)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.22.0->pythainlp) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.22.0->pythainlp) (1.24.3)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.22.0->pythainlp) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.22.0->pythainlp) (2019.9.11)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from nltk>=3.3->pythainlp) (1.12.0)
# Building wheels for collected packages: nltk
#   Building wheel for nltk (setup.py) ... done
#   Created wheel for nltk: filename=nltk-3.4.5-cp36-none-any.whl size=1449908 sha256=99c493143eefac115b35b62f9190d2bcb2c5d1a4c45e273cdf7b0375eba08f53
#   Stored in directory: /root/.cache/pip/wheels/96/86/f6/68ab24c23f207c0077381a5e3904b2815136b879538a24b483
# Successfully built nltk
# ERROR: google-colab 1.0.0 has requirement requests~=2.21.0, but you'll have requests 2.22.0 which is incompatible.
# ERROR: datascience 0.10.6 has requirement folium==0.2.1, but you'll have folium 0.8.3 which is incompatible.
# Installing collected packages: tinydb, requests, nltk, pythainlp
#   Found existing installation: requests 2.21.0
#     Uninstalling requests-2.21.0:
#       Successfully uninstalled requests-2.21.0
#   Found existing installation: nltk 3.2.5
#     Uninstalling nltk-3.2.5:
#       Successfully uninstalled nltk-3.2.5
# Successfully installed nltk-3.4.5 pythainlp-2.1.dev8 requests-2.22.0 tinydb-3.15.1

# %%
from pythainlp.corpus import thai_words

# %%
words=list(thai_words())

# %%
def find_word(word):
  return [i for i in words if i.startswith(word)]

# %%
find_word("แม")
# Out:
# ['แม่กองธรรมสนามหลวง',
#  'แมมโมแกรม',
#  'แมงดาจาน',
#  'แมรี่แลนด์',
#  'แมนฯยู',
#  'แมกไซไซ',
#  'แมคนีเซียม',
#  'แม่แก่',
#  'แม่รีแม่แรด',
#  'แม่น้ำ',
#  'แม่เหล็ก',
#  'แมงไฟเดือนห้า',
#  'แมลงแดง',
#  'แมลงปอ',
#  'แมนเนอร์เจอร์',
#  'แมงกาย',
#  'แม่พระ',
#  'แม้กระทั่ง',
#  'แมงอ่อนช้อย',
#  'แมวดาว',
#  'แม๊กกาซีน',
#  'แม่ลูกอ่อน',
#  'แมนิค',
#  'แม่ตะงาว',
#  'แมลงเม่า',
#  'แมนเชเตอร์ยูไนเต๊ด',
#  'แม่โพสพ',
#  'แม่บันได',
#  'แมกนิจูด',
#  'แม่หินบด',
#  'แม่นั่งภาวนา',
#  'แม่ย่านาง',
#  'แมลงนูน',
#  'แม่ฝา',
#  'แม่ลาย',
#  'แมนเชสเตอร์ ซิตี้',
#  'แมนซิตี้',
#  'แม่บ้าน',
#  'แม่แรง',
#  'แม้นเขียน',
#  'แม้วะ',
#  'แม่หนัก',
#  'แม่นาง',
#  'แมงดาทะเล',
#  'แมคเคอเรล',
#  'แมลงป่อง',
#  'แม่ม่ายลองไน',
#  'แมวเซา',
#  'แม่เจ้าโว้ย',
#  'แม่ออน',
#  'แม่อยู่หัว',
#  'แม่เจ้า',
#  'แมทซาจูเซตต์',
#  'แมนฮัตตั้น',
#  'แม่กระชังหน้าใหญ่',
#  'แม็กกาซีน',
#  'แมลงปีกแข็ง',
#  'แมะ',
#  'แมคโครไบโอติก',
#  'แม่ตาย',
#  'แม่ร้าง',
#  'แม่เจ้าเรือน',
#  'แม่สายบัวแต่งตัวค้าง',
#  'แม้แต่',
#  'แม่มด',
#  'แมลลิค',
#  'แม่ยาย',
#  'แมเนจเม้นท์',
#  'แมง',
#  'แมลงวัน',
#  'แมลงดาโป้งเป้ง',
#  'แม่นยำ',
#  'แม่แคร่',
#  'แมชชิ่ง',
#  'แมลบ',
#  'แมกซ์',
#  'แมลงสาบ',
#  'แมค',
#  'แมลงแคง',
#  'แม่หม้าย',
#  'แม่ระมาด',
#  'แมเนเจอร์ มีเดีย กรุ๊ป',
#  'แม่เจ้าประคุณ',
#  'แม่ไม้',
#  'แม้ว',
#  'แมร',
#  'แม่เบี้ย',
#  'แม่ยกครัวลงล่าง',
#  'แม่ปะ',
#  'แม่กุญแจ',
#  'แมนเดลา',
#  'แมร์',
#  'แม่คงคา',
#  'แมชีนเนอรี่',
#  'แม่ยก',
#  'แม่บท',
#  'แม่ย่างม้าเหาะ',
#  'แม่จัน',
#  'แมงกวาง',
#  'แมนชั่น',
#  'แมวมอง',
#  'แมวขโมย',
#  'แมสคอต',
#  'แมนฮัตตัน',
#  'แม่อยั่วเมือง',
#  'แมลงดาขี้ควาย',
#  'แมเนเจอร์',
#  'แมลงสีเสียด',
#  'แม่วิน',
#  'แม่เล้า',
#  'แม่เหย้าแม่เรือน',
#  'แม่ธรณี',
#  'แมคโคร',
#  'แมงดาทะเลหางเหลี่ยม',
#  'แมมบ้า',
#  'แมสซาชูเซ็ทส์',
#  'แมงฮอด',
#  'แม่ม่าย',
#  'แม่งม้าง',
#  'แม่พระคงคา',
#  'แมงดาทะเลหางกลม',
#  'แม้นว่า',
#  'แมก',
#  'แมกม่า',
#  'แม่หยั่วเมือง',
#  'แมงช้าง',
#  'แม่เป้ง',
#  'แมวคราว',
#  'แมนจู',
#  'แมกนีเซีย',
#  'แมมโบ้',
#  'แม่ฮ่องสอน',
#  'แม่เลี้ยง',
#  'แมว',
#  'แมลงวันหัวเขียว',
#  'แมลงดานา',
#  'แม่ซื้อ',
#  'แม่แบบ',
#  'แมลงจิ้มฟันจระเข้',
#  'แม่ผัว',
#  'แมลงวันผลไม้',
#  'แมคไควร์รี่',
#  'แมกนีเซียมซัลเฟต',
#  'แม่วี',
#  'แมสซาชูเซตส์',
#  'แมตช์',
#  'แมร่ง',
#  'แม่สื่อแม่ชัก ไม่ได้เจ้าตัว เอาวัวพันหลัก',
#  'แม้แต่น้อย',
#  'แม่กระแชง',
#  'แมนจูเรีย',
#  'แม่เตาไฟ',
#  'แม่ม่ายผัวร้าง',
#  'แมวน้ำ',
#  'แมงคา',
#  'แม่ค้า',
#  'แมลงทับ',
#  'แม่กอง',
#  'แมยิสเตร็ด',
#  'แมงดา',
#  'แมงมุม',
#  'แมคอินทอช',
#  'แมลงทับเล็ก',
#  'แม้',
#  'แมงแงว',
#  'แมคโดนัลด์',
#  'แมลงมุม',
#  'แม่ชี',
#  'แมลงไฟ',
#  'แม่ยั่วเมือง',
#  'แม่ท่า',
#  'แม้กระนั้น',
#  'แมนฮัทตัน',
#  'แมซซาชูเซตส์',
#  'แมงคาเรือง',
#  'แม็ตต์',
#  'แม่ฟ้าหลวง',
#  'แม้น',
#  'แมลงดาสวน',
#  'แมลงช้าง',
#  'แม่ครัว',
#  'แมสซาชูเซ็ตส์',
#  'แมรี่',
#  'แม่บ้านแม่เรือน',
#  'แมงหางแดง',
#  'แมลงดา',
#  'แม็กซ์',
#  'แม่น้ำคงคา',
#  'แมส',
#  'แม็พ',
#  'แมลงวันทอง',
#  'แมงดาไฟ',
#  'แม่กระได',
#  'แมงลัก',
#  'แม่ร้า',
#  'แม็กนีเซียม',
#  'แม่พิมพ์',
#  'แม่เฒ่า',
#  'แม่นตรง',
#  'แมงกานิน',
#  'แม่ค้าหาบเร่',
#  'แมลงภู่',
#  'แม่สื่อ',
#  'แม่ม่ายทรงเครื่อง',
#  'แม่งาน',
#  'แมสเสด',
#  'แมกซ์เวลล์',
#  'แมงดาถ้วย',
#  'แมน',
#  'แม่นมั่น',
#  'แม่พระธรณี',
#  'แมชีน',
#  'แมกนีเซียม',
#  'แม่นม',
#  'แม่เพลง',
#  'แม่เรือน',
#  'แม่สื่อแม่ชัก',
#  'แม่พันธุ์',
#  'แมลงวันสเปน',
#  'แมกกาซีน',
#  'แม่แปรก',
#  'แมลง',
#  'แม่ศรี',
#  'แม่คุณ',
#  'แมริแลนด์',
#  'แม่หญิงแม่หยัง',
#  'แม่สี',
#  'แมนยูฯ',
#  'แม้ว่า',
#  'แม็ก',
#  'แม่กระชังก้นรั่ว',
#  'แมชชีน',
#  'แมนเชสเตอร์',
#  'แม่สะเรียง',
#  'แมลงดำหนาม',
#  'แม่คู่',
#  'แม่กองบาลีสนามหลวง',
#  'แมนฯ ซิตี้',
#  'แมงปากจอบ',
#  'แม่เดาะคันชั่ง',
#  'แม่ย้าว',
#  'แม่น',
#  'แมลงหวี่',
#  'แม่ทัพ',
#  'แมงกานีส',
#  'แมนดาริน',
#  'แม็คโครไบโอติกส์',
#  'แมวป่า',
#  'แมรีแลนด์',
#  'แม่',
#  'แมโครฝาจ',
#  'แมวหง่าว',
#  'แมงกะพรุน',
#  'แมลงไฟเดือนห้า',
#  'แมลงแสง']
